# %% [markdown]
# # Test case 6

# %% [markdown]
# Import requests library to work with REST API requests.

# %%
import requests as rq
from IPython.display import Image

# %% [markdown]
# #### Let's try to check out book6 for once now

# %%
checkout = rq.get("http://www.trainno.ru/booking/7").json() # the ID of our book is 7 now
print(checkout['status'] + "; checkout order ID: " + str(checkout['data']['order_id']))
# Out:
# HTTP_200_OK; checkout order ID: 36

# %% [markdown]
# #### There is no exception here. Let's confirm (by librarian) the state of checkout

# %%
Image(filename ="img/screen3.png")

# %% [markdown]
# #### Alright. Let's try to check out this book again:

# %%
checkout = rq.get("http://www.trainno.ru/booking/7").json() # the ID of our book is 7 now
print(checkout['status'] + "; checkout order ID: " + str(checkout['data']['order_id']))
# Out:
# HTTP_200_OK; checkout order ID: 37

# %% [markdown]
# #### But now librarian will see that user with ID 1 has booked the copy of the book (same document ID) twice.

# %%
Image(filename ="img/screen4.png")

# %% [markdown]
# #### The librarian can simply ignore this state and do not accept order. Status will be 0, not 1.
# ---
