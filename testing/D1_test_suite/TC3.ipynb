# %% [markdown]
# # Test case 1

# %% [markdown]
# #### Import _requests_ library to work with REST API requests.

# %%
import requests as rq
from IPython.display import Image

# %% [markdown]
# #### Let's checkout book 5 now

# %%
checkout = rq.get("http://www.trainno.ru/booking/6").json() # the ID of our book is 6 now
print(checkout['status'] + "; date of creation: " + str(checkout['data']['date_created']) + '; date of returning: ' + str(checkout['data']['date_return']))
# Out:
# HTTP_200_OK; date of creation: 2018-02-07; date of returning: None

# %% [markdown]
# #### With program POSTMAN we sending PATCH request on _/orders/{order-id}_ to accept the request as librarian will do, the picture of process below

# %%
Image(filename ="img/screen.png")

# %% [markdown]
# #### And now check again

# %%
checkout = rq.get("http://www.trainno.ru/orders/32").json()
print("order id: " + str(checkout['data']['order_id']) + "; date of creation: " + str(checkout['data']['date_created']) + '; date of returning: ' + str(checkout['data']['date_return']))
# Out:
# order id: 32; date of creation: 2018-02-07; date of returning: 2018-03-07

# %% [markdown]
# #### We tried to get a book and we got it, as we are faculty we got it for 4 weeks.
# ---
